# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import L2

import visualkeras
from PIL import ImageFont
from ann_visualizer.visualize import ann_viz


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Loading with ImageDataGenerator

# %%
# Path to the directory containing the training images
train_dir = 'Train:Test/Train/'
test_dir = 'Train:Test/Test/'
print(os.listdir(train_dir))
print(os.listdir(test_dir))
# Out:
# ['.DS_Store', 'VeryMildDemented', 'ModerateDemented', 'MildDemented', 'NonDemented']
# ['.DS_Store', 'VeryMildDemented', 'ModerateDemented', 'MildDemented', 'NonDemented']

# %%
image_size = (50, 50)
# Image dimensions

# %%
# Creating an instance of the ImageDataGenerator with data augmentation and validation split
datagen = ImageDataGenerator(
    rescale=1.0 / 255,         # Rescale pixel values between 0 and 1
#     horizontal_flip=True,     # Randomly flip images horizontally
#     rotation_range=20,         # Randomly rotate images by 20 degrees
#     vertical_flip=True,        # Randomly flip images vertically
#     Flips and rotations dont really help
    validation_split=0.2       # Split 20% of data for validation
)


# Creating an instance of the ImageDataGenerator for the Testing
test_datagen = ImageDataGenerator(
    rescale=1.0 / 255,         # Rescale pixel values between 0 and 1
)

# %%
# Generating training data from the images in the specified directory
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    subset='training'# Use subset 'training' for training data
)
# Out:
# Found 19032 images belonging to 4 classes.

# %%
# Generating validation data from the images in the specified directory
validation_generator = datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    subset='validation'        # Use subset 'validation' for validation data
)
# Out:
# Found 4757 images belonging to 4 classes.

# %%
# Generating Testing data from the images in the specified directory
testing_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
     shuffle = False
)
# Out:
# Found 10195 images belonging to 4 classes.

# %% [markdown]
# # Build Model

# %%
model = Sequential()
model.add(Conv2D(64, (3,3), 1, activation = 'relu', input_shape =(50,50,3)))
model.add(Conv2D(64, (3,3), 1, activation = 'relu'))
model.add(MaxPooling2D(2,2))

# Adding a Dropout Layer
model.add(Dropout(0.2)) # dropout on previous activations

model.add(Conv2D(128, (3,3), 1, activation = 'relu'))
model.add(Conv2D(128, (3,3), 1, activation = 'relu'))
model.add(MaxPooling2D(2,2))

# Adding a Dropout Layer
model.add(Dropout(0.4)) # dropout on previous activations

model.add(Conv2D(256, (3,3), 1, activation = 'relu'))
model.add(Conv2D(256, (3,3), 1, activation = 'relu'))
model.add(Conv2D(128, (3,3), 1, activation = 'relu'))
model.add(MaxPooling2D(2,2))



model.add(Flatten())

# Adding a Dropout Layer
model.add(Dropout(0.1)) # dropout on previous activations

model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))
# Out:
# Metal device set to: Apple M2 Pro
# 2023-07-20 18:24:20.435127: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-20 18:24:20.435253: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
opt = Adam(learning_rate = 1e-3, beta_1 = 0.9, beta_2 = 0.999 ) # typical parameters

# %%
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy','AUC'] )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 9, 9, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 256)         590080
#
#  conv2d_6 (Conv2D)           (None, 3, 3, 128)         295040
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 256)               33024
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1,514,884
# Trainable params: 1,514,884
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fit Model

# %%
#  will use validation loss: stopping to prevent overfitting.
trainCallback = EarlyStopping(monitor='loss', min_delta = 1e-6, patience = 5)
# tensorboard = tf.keras.callbacks.TensorBoard(log_dir='logs/drop2-4',histogram_freq=1)

# %%
# Training the model
history_model = model.fit(
    train_generator,
    epochs=35,
    validation_data=validation_generator,
    callbacks=[trainCallback]
)
# Out:
# Epoch 1/35
# 2023-07-20 18:24:20.660333: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-07-20 18:24:20.981829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 594/595 [============================>.] - ETA: 0s - loss: 1.2411 - accuracy: 0.3773 - auc: 0.6709
# 2023-07-20 18:24:34.879867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 595/595 [==============================] - 16s 26ms/step - loss: 1.2407 - accuracy: 0.3776 - auc: 0.6712 - val_loss: 0.9168 - val_accuracy: 0.5655 - val_auc: 0.8426
# Epoch 2/35
# 595/595 [==============================] - 15s 25ms/step - loss: 0.8773 - accuracy: 0.5781 - auc: 0.8510 - val_loss: 0.7653 - val_accuracy: 0.6428 - val_auc: 0.8893
# Epoch 3/35
# 595/595 [==============================] - 15s 25ms/step - loss: 0.7803 - accuracy: 0.6266 - auc: 0.8816 - val_loss: 0.6903 - val_accuracy: 0.6845 - val_auc: 0.9121
# Epoch 4/35
# 595/595 [==============================] - 15s 25ms/step - loss: 0.7095 - accuracy: 0.6689 - auc: 0.9040 - val_loss: 0.6013 - val_accuracy: 0.7259 - val_auc: 0.9315
# Epoch 5/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.6464 - accuracy: 0.7039 - auc: 0.9214 - val_loss: 0.5809 - val_accuracy: 0.7463 - val_auc: 0.9392
# Epoch 6/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.5880 - accuracy: 0.7345 - auc: 0.9352 - val_loss: 0.5560 - val_accuracy: 0.7469 - val_auc: 0.9425
# Epoch 7/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.5451 - accuracy: 0.7528 - auc: 0.9445 - val_loss: 0.4711 - val_accuracy: 0.7915 - val_auc: 0.9587
# Epoch 8/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.4963 - accuracy: 0.7801 - auc: 0.9544 - val_loss: 0.4410 - val_accuracy: 0.8028 - val_auc: 0.9639
# Epoch 9/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.4598 - accuracy: 0.8010 - auc: 0.9607 - val_loss: 0.4196 - val_accuracy: 0.8142 - val_auc: 0.9671
# Epoch 10/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.4265 - accuracy: 0.8159 - auc: 0.9662 - val_loss: 0.3989 - val_accuracy: 0.8278 - val_auc: 0.9702
# Epoch 11/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.3929 - accuracy: 0.8341 - auc: 0.9715 - val_loss: 0.3915 - val_accuracy: 0.8348 - val_auc: 0.9711
# Epoch 12/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.3555 - accuracy: 0.8488 - auc: 0.9765 - val_loss: 0.3427 - val_accuracy: 0.8585 - val_auc: 0.9782
# Epoch 13/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.3281 - accuracy: 0.8667 - auc: 0.9799 - val_loss: 0.2800 - val_accuracy: 0.8791 - val_auc: 0.9852
# Epoch 14/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.3084 - accuracy: 0.8734 - auc: 0.9821 - val_loss: 0.2968 - val_accuracy: 0.8774 - val_auc: 0.9834
# Epoch 15/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.2783 - accuracy: 0.8875 - auc: 0.9853 - val_loss: 0.3264 - val_accuracy: 0.8699 - val_auc: 0.9807
# Epoch 16/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.2562 - accuracy: 0.8989 - auc: 0.9874 - val_loss: 0.2815 - val_accuracy: 0.8890 - val_auc: 0.9852
# Epoch 17/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.2454 - accuracy: 0.9021 - auc: 0.9884 - val_loss: 0.2663 - val_accuracy: 0.8873 - val_auc: 0.9869
# Epoch 18/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.2241 - accuracy: 0.9113 - auc: 0.9903 - val_loss: 0.2547 - val_accuracy: 0.8934 - val_auc: 0.9878
# Epoch 19/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.2159 - accuracy: 0.9175 - auc: 0.9909 - val_loss: 0.2362 - val_accuracy: 0.9058 - val_auc: 0.9895
# Epoch 20/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1998 - accuracy: 0.9233 - auc: 0.9922 - val_loss: 0.2277 - val_accuracy: 0.9138 - val_auc: 0.9901
# Epoch 21/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1872 - accuracy: 0.9263 - auc: 0.9931 - val_loss: 0.2207 - val_accuracy: 0.9119 - val_auc: 0.9905
# Epoch 22/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1780 - accuracy: 0.9322 - auc: 0.9935 - val_loss: 0.2252 - val_accuracy: 0.9102 - val_auc: 0.9904
# Epoch 23/35
# 595/595 [==============================] - 61s 103ms/step - loss: 0.1798 - accuracy: 0.9308 - auc: 0.9934 - val_loss: 0.2064 - val_accuracy: 0.9189 - val_auc: 0.9917
# Epoch 24/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1605 - accuracy: 0.9410 - auc: 0.9945 - val_loss: 0.2210 - val_accuracy: 0.9186 - val_auc: 0.9904
# Epoch 25/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1459 - accuracy: 0.9456 - auc: 0.9954 - val_loss: 0.1969 - val_accuracy: 0.9287 - val_auc: 0.9924
# Epoch 26/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1588 - accuracy: 0.9410 - auc: 0.9947 - val_loss: 0.2220 - val_accuracy: 0.9186 - val_auc: 0.9904
# Epoch 27/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1291 - accuracy: 0.9532 - auc: 0.9962 - val_loss: 0.2115 - val_accuracy: 0.9201 - val_auc: 0.9912
# Epoch 28/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1360 - accuracy: 0.9511 - auc: 0.9958 - val_loss: 0.1904 - val_accuracy: 0.9289 - val_auc: 0.9926
# Epoch 29/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1249 - accuracy: 0.9532 - auc: 0.9965 - val_loss: 0.2181 - val_accuracy: 0.9218 - val_auc: 0.9905
# Epoch 30/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1260 - accuracy: 0.9549 - auc: 0.9963 - val_loss: 0.1793 - val_accuracy: 0.9289 - val_auc: 0.9937
# Epoch 31/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1197 - accuracy: 0.9564 - auc: 0.9966 - val_loss: 0.1902 - val_accuracy: 0.9310 - val_auc: 0.9924
# Epoch 32/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1120 - accuracy: 0.9603 - auc: 0.9969 - val_loss: 0.1736 - val_accuracy: 0.9371 - val_auc: 0.9939
# Epoch 33/35
# 595/595 [==============================] - 208s 351ms/step - loss: 0.1176 - accuracy: 0.9566 - auc: 0.9967 - val_loss: 0.2520 - val_accuracy: 0.9107 - val_auc: 0.9873
# Epoch 34/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.1159 - accuracy: 0.9578 - auc: 0.9968 - val_loss: 0.1839 - val_accuracy: 0.9327 - val_auc: 0.9931
# Epoch 35/35
# 595/595 [==============================] - 15s 26ms/step - loss: 0.0998 - accuracy: 0.9658 - auc: 0.9974 - val_loss: 0.1951 - val_accuracy: 0.9302 - val_auc: 0.9926

# %% [markdown]
# # Evaluate Model

# %%
# Model evaluation
model.evaluate(testing_generator)
# Out:
# 319/319 [==============================] - 5s 16ms/step - loss: 0.1939 - accuracy: 0.9341 - auc: 0.9923
# [0.19389981031417847, 0.9340853095054626, 0.9922690987586975]

# %%
# Model prediction
y_true = testing_generator.classes
y_pred_probs = model.predict(testing_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
#  12/319 [>.............................] - ETA: 3s
# 2023-07-20 18:37:20.225184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 319/319 [==============================] - 4s 11ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Create confusion matrix display
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
train_history_model = pd.DataFrame(history_model.history)
train_history_model.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_history_model[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_history_model[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# # Visualize the Model Architecture

# %%
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=603x292>

# %%
# ann_viz(model, view=True, filename="Modelv2", title="CNN Model v2")

# %% [markdown]
# # Evaluation Using TensorBoard

# %% [markdown]
# ## Comparing Different Accuracy per Epoch of Validation Testing

# %% [markdown]
# ![Screenshot%202023-07-20%20at%207.11.33%20PM.jpg](attachment:Screenshot%202023-07-20%20at%207.11.33%20PM.jpg)

# %% [markdown]
# ### When using TensorBoard to evalute the different dropout regularization methods we used, we can conclude that a dropout of 0.2 after the first maxpool and 0.4 after second maxpool and 0.1 after the flattening, works the best

# %% [markdown]
# ### And compared to our v2 model we have a boost in accuracy about 3 points

# %% [markdown]
# ![Screenshot%202023-07-20%20at%2012.55.45%20PM.jpg](attachment:Screenshot%202023-07-20%20at%2012.55.45%20PM.jpg)

# %% [markdown]
# # Next step, Use a prebuilt Neural Network and tune it for a better model
